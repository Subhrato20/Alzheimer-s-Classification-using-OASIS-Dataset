# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhrato20/Alzheimer-s-Classification-using-OASIS-Dataset/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tasks:**
# - Data Loading and Preprocessing
# - Pattern Detection with Machine Learning
# - Deviation Detection
# - Visualization of results
# - Alerting system
# - Motor Current Data Analysis
